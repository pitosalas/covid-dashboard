# %%
import test_data as td
import pandas as pd
import numpy as np
from scipy.interpolate import make_interp_spline, BSpline
import matplotlib.pyplot as plt

# %%
d = td.TestData()

# %%
d.setup()

# %%
df = d.cdc

# %%
df["roll"] = d.cdc.iloc[:,3].rolling(window=5).mean().reset_index(0, drop=True)

# %%
df['EHE'] = pd.to_numeric(df['Excess Higher Estimate'],errors='coerce')

# %%
df.plot()

# %%
df.index.values
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
spl = make_interp_spline(df.index.values,df["EHE"])

# %%
xnew = np.linspace(0, 10, 200)

# %%
y_smooth = spl(xnew)

# %%
plt.plot(y_smooth)
plt.show()
