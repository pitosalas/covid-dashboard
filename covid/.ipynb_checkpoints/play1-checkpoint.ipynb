# %%
import data
import seaborn as sns
import matplotlib.pyplot as plt

# %%
startdate = "2020-04-01"
variables = ["deaths", "cases"]
states = ["Massachusetts", "New York"]
df = data.read_data(startdate, states, variables)

# %%
df.head()
# Out:
#           date          state variable     value
# 106 2020-04-02  Massachusetts    cases    8966.0
# 107 2020-04-02       New York    cases   92971.0
# 108 2020-04-03  Massachusetts    cases   10402.0
# 109 2020-04-03       New York    cases  103651.0
# 110 2020-04-04  Massachusetts    cases   11736.0

# %%
plt.style.use('seaborn-darkgrid')
sns.set()
g = sns.FacetGrid(df, col='state', hue='variable', sharex=True, sharey=False, height=10, aspect=1)
g = g.map(plt.plot, "date", "value")

# %%
g.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-6773f9cc59fc> in <module>
# ----> 1 g.display()
#
# AttributeError: 'FacetGrid' object has no attribute 'display'
